# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from analysis import *

# %matplotlib inline

# %%
dirname = '/data/save_weights_tf1.10.1/cifar10/alexnet/'

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 3, 1)
plot_training_curves(1.6, 'fgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False)
plt.subplot(1, 3, 2)
plot_training_curves(1.6, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False, ylabel=False)
plt.subplot(1, 3, 3)
plot_training_curves(1.3, 'wrm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False)
plt.tight_layout()
plt.savefig('/data/Figures_ICLR/cifar10_alexnet_trainingcurves.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
dirname = '/data/save_weights_tf1.10.1/cifar10/alexnet_elu/'

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 3, 1)
plot_training_curves(1.6, 'fgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False)
plt.title('ELU-AlexNet FGM')
plt.subplot(1, 3, 2)
plot_training_curves(1.6, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False, ylabel=False)
plt.title('ELU-AlexNet PGM')
plt.subplot(1, 3, 3)
plot_training_curves(1.3, 'wrm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False)
plt.title('ELU-AlexNet WRM')
plt.tight_layout()
plt.savefig('/data/Figures_ICLR/cifar10_alexnet_elu_trainingcurves.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
dirname = '/data/save_weights_tf1.10.1/cifar10/inception/'

plt.figure(figsize=(10., 3.5))
plt.subplot(1, 4, 1)
plot_training_curves(1.6, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False)
plt.title('Inception PGM')
plt.subplot(1, 4, 2)
plot_training_curves(1.0, 'wrm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False, legend=False)
plt.title('Inception WRM')

dirname = '/data/save_weights_tf1.10.1/cifar10/resnet/'

plt.subplot(1, 4, 3)
plot_training_curves(2.5, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False, legend=False)
plt.title('ResNet PGM')
plt.subplot(1, 4, 4)
plot_training_curves(1.6, 'wrm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False)
plt.title('ResNet WRM')
plt.tight_layout()
plt.savefig('/data/Figures_ICLR/cifar10_inception_resnet_trainingcurves.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
dirname = '/data/save_weights_tf1.10.1/cifar10/alexnet_norminfattacks_eps0.1/'

plt.figure(figsize=(10., 3.5))
plt.subplot(1, 4, 1)
plot_training_curves(1.3, 'fgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, legend=False)
plt.title(r'AlexNet FGM $\ell_\infty$ ($\epsilon$ = 0.1)')
plt.subplot(1, 4, 2)
plot_training_curves(1.6, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False, legend=False)
plt.title(r'AlexNet PGM $\ell_\infty$ ($\epsilon$ = 0.1)')

dirname = '/data/save_weights_tf1.10.1/cifar10/alexnet_norminfattacks_eps0.3/'

plt.subplot(1, 4, 3)
plot_training_curves(1.3, 'fgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False, legend=False)
plt.title(r'AlexNet FGM $\ell_\infty$ ($\epsilon$ = 0.3)')
plt.subplot(1, 4, 4)
plot_training_curves(1.3, 'pgm', dirname, ylim=(0, 1.1), num_batches_per_epoch=390, ylabel=False)
plt.title(r'AlexNet PGM $\ell_\infty$ ($\epsilon$ = 0.3)')

plt.tight_layout()
plt.savefig('/data/Figures_ICLR/cifar10_alexnet_linf_trainingcurves.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()
